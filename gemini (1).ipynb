# %%
# !pip install gradio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 MB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.9/321.9 kB 22.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 77.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !pip install transformers

# %%
import google.generativeai as genai
import requests
from PIL import Image
import io

genai.configure(api_key="AIzaSyAbWYF9HT2e0RpLnTu1kiQrEi-eFA2pAnk")

def describe_landmark(image_path):
    """Send image to Gemini AI and get a landmark description."""
    with open(image_path, "rb") as img_file:
        img_data = img_file.read()

    response = genai.GenerativeModel("gemini-pro-vision").generate_content([img_data])
    return response.text if response else "Description not available."

def main():
    print("Welcome to AI Landmark Description App!")
    image_path = input("Enter the path of the landmark image: ")

    try:
        img = Image.open(image_path)
        img.show()
        description = describe_landmark(image_path)
        print("\nLandmark Description:")
        print(description)
    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    main()
# Out:
# Welcome to AI Landmark Description App!
# Enter the path of the landmark image: /content/effile tower.png
# Error: Could not create `Blob`, expected `Blob`, `dict` or an `Image` type(`PIL.Image.Image` or `IPython.display.Image`).
# Got a: <class 'bytes'>
# ...

# %%
# prompt: Error: Could not create `Blob`, expected `Blob`, `dict` or an `Image` type(`PIL.Image.Image` or `IPython.display.Image`)

import google.generativeai as genai
import requests
from PIL import Image
import io
# !pip install gradio
# !pip install transformers

genai.configure(api_key="AIzaSyAbWYF9HT2e0RpLnTu1kiQrEi-eFA2pAnk")

def describe_landmark(image_path):
    """Send image to Gemini AI and get a landmark description."""
    try:
      with open(image_path, "rb") as img_file:
          img_data = img_file.read()

      response = genai.GenerativeModel("gemini-pro-vision").generate_content(img_data)
      return response.text if response else "Description not available."
    except Exception as e:
      return f"Error during API call: {e}"


def main():
    print("Welcome to AI Landmark Description App!")
    image_path = input("Enter the path of the landmark image: ")

    try:
        img = Image.open(image_path)
        img.show()
        description = describe_landmark(image_path)
        print("\nLandmark Description:")
        print(description)
    except FileNotFoundError:
        print(f"Error: Image file not found at {image_path}")
    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    main()
# Out:
# ...
# Welcome to AI Landmark Description App!
# Enter the path of the landmark image: /content/effile tower.png
#
# Landmark Description:
# Error during API call: Could not create `Blob`, expected `Blob`, `dict` or an `Image` type(`PIL.Image.Image` or `IPython.display.Image`).
# Got a: <class 'int'>
# Value: 137

# %%
# prompt: Error during API call: Could not create `Blob`, expected `Blob`, `dict` or an `Image` type(`PIL.Image.Image` or `IPython.display.Image`).

import google.generativeai as genai
import requests
from PIL import Image
import io

# Install necessary libraries if not already installed
# !pip install gradio transformers

# Configure the Gemini API key
genai.configure(api_key="AIzaSyAbWYF9HT2e0RpLnTu1kiQrEi-eFA2pAnk")


def describe_landmark(image_path):
    """Send image to Gemini AI and get a landmark description."""
    try:
        with open(image_path, "rb") as img_file:
            img_data = img_file.read()

        # Correct the input format for generate_content.  It needs a list.
        response = genai.GenerativeModel("gemini-pro-vision").generate_content([img_data])
        return response.text if response else "Description not available."
    except Exception as e:
        return f"Error during API call: {e}"


def main():
    print("Welcome to AI Mark Description App!")
    image_path = input("Enter the path of the landmark image: ")

    try:
        img = Image.open("images/taj_mahal.jpg"  )
        # img.show()  # This might not work in all environments, especially colab
        description = describe_landmark(image_path)
        print("\nLandmark Description:")
        print(description)
    except FileNotFoundError:
        print(f"Error: Image file not found at {image_path}")
    except Exception as e:
        print(f"Error: {e}")


if __name__ == "__main__":
    main()
# Out:
# Welcome to AI Mark Description App!
# Enter the path of the landmark image: effile tower.png
# Error: Image file not found at effile tower.png
